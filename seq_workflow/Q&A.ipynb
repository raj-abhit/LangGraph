# %%
from langgraph.graph import StateGraph,START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="llama-3.1-8b-instant")

# %%
class LLMState(TypedDict):
    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    question = state['question']
    prompt = f"Answer the following question: {question}"
    answer = model.invoke(prompt).content
    state['answer'] = answer
    return state

# %%
graph = StateGraph(LLMState)

graph.add_node('llm_qa',llm_qa)

graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

workfolow = graph.compile()

# %%
initial_state = {'question': 'how far is the moon from earth?'}
final_state = workfolow.invoke(initial_state)

print(final_state)
# Out:
# {'question': 'how far is the moon from earth?', 'answer': 'The average distance from the Earth to the Moon is approximately 384,400 kilometers (238,900 miles).'}
